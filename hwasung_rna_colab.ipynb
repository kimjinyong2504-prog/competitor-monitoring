# %% [markdown]
# # 화승알앤에이 실시간 분석 보고서 생성 (Google Colab)
#
# 이 노트북은 Google Colab에서 화승알앤에이의 기업 정보를 DART API와 네이버 뉴스 API를 통해 수집하여 HTML 보고서를 생성합니다.

# %% [markdown]
# ## 1. 필요한 라이브러리 설치

# %%
# !pip install requests -q

# %% [markdown]
# ## 2. API 키 설정

# %%
# API 키 설정
DART_API_KEY = "5523e4e6b24ce622cff0e56500dcccad55bcb26f"
NAVER_CLIENT_ID = "00q938ugMTSfuzjWuLk4"
NAVER_CLIENT_SECRET = "MrIG7TWaGW"

# 기업 정보
COMPANY_NAME = "화승알앤에이"
CORP_CODE = "378850"  # 화승알앤에이 고유번호

print("API 키 설정 완료")
